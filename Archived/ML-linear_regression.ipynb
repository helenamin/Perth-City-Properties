# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_json("http://127.0.0.1:5500/api/v1.0/perthcity")

# %%
df
# Out:
#                       address                           agent  bathrooms  \
# 0            1/10 Pendal Lane                    not recorded          2
# 1          1/10 Wright Street                    not recorded          1
# 2       1/308 Stirling Street                    Peter Thomas          1
# 3         1/33 Windsor Street                    not recorded          2
# 4        1/478 William Street                    not recorded          2
# ...                       ...                             ...        ...
# 1615        25/20 Pendal Lane     For Sale By Owner Australia          2
# 1616  21/145 Newcastle Street   Realmark Central - East Perth          2
# 1617   18/76 Newcastle Street     Abel Property - Leederville          2
# 1618        10/89 Lake Street  BOSS Real Estate - Northbridge          2
# 1619        13/10 Pendal Lane         MLG Realty - EAST PERTH          2
#
#       bedrooms  building_size  built_date  car_space  \
# 0            2             90        2003          1
# 1            2             62        1979          1
# 2            2             59        1965          1
# 3            2             56        2016          1
# 4            2             90        2009          2
# ...        ...            ...         ...        ...
# 1615         3            161        2003          2
# 1616         3            104        2009          1
# 1617         2             88        2007          1
# 1618         3             99        2009          1
# 1619         2             90        2003          1
#
#                                      full_address  land_size        lat  \
# 0                  1/10 Pendal Lane Perth WA 6000         96 -31.943275
# 1                1/10 Wright Street Perth WA 6000         62 -31.940382
# 2             1/308 Stirling Street Perth WA 6000         59 -31.942238
# 3               1/33 Windsor Street Perth WA 6000         97 -31.944320
# 4              1/478 William Street Perth WA 6000        129 -31.941260
# ...                                           ...        ...        ...
# 1615        25/20 Pendal Lane Northbridge WA 6003        203 -31.942841
# 1616  21/145 Newcastle Street Northbridge WA 6003        151 -31.946895
# 1617   18/76 Newcastle Street Northbridge WA 6003        123 -31.948372
# 1618        10/89 Lake Street Northbridge WA 6003        139 -31.945441
# 1619        13/10 Pendal Lane Northbridge WA 6003        117 -31.943275
#
#              lng  postcode   price property_type  rent rent_date  sale_id  \
# 0     115.856012      6000  359000     Apartment   470   2010-01        1
# 1     115.873713      6000  355000     Townhouse   340   2018-01        2
# 2     115.869436      6000  325000          Unit   300   2012-01        3
# 3     115.874520      6000  360000     Apartment   360   2020-01        4
# 4     115.863844      6000  523000     Apartment   475   2020-01        5
# ...          ...       ...     ...           ...   ...       ...      ...
# 1615  115.856104      6003  724999     Townhouse   590   2018-01     1616
# 1616  115.861846      6003  614000     Apartment     0   1900-01     1617
# 1617  115.866086      6003  535000     Apartment   530   2014-01     1618
# 1618  115.857860      6003  590000     Apartment   540   2011-01     1619
# 1619  115.856012      6003  560000     Apartment     0   1900-01     1620
#
#      sold_date state       suburb
# 0      2020-01    WA        Perth
# 1      2020-01    WA        Perth
# 2      2021-01    WA        Perth
# 3      2020-01    WA        Perth
# 4      2021-01    WA        Perth
# ...        ...   ...          ...
# 1615   2013-01    WA  Northbridge
# 1616   2013-01    WA  Northbridge
# 1617   2013-01    WA  Northbridge
# 1618   2013-01    WA  Northbridge
# 1619   2013-01    WA  Northbridge
#
# [1620 rows x 20 columns]

# %%
#only getting landed properties for the machine learning
house = df[(df['property_type']=='House') | (df['property_type']=='Villa') | (df['property_type']=='Townhouse')]
house
# Out:
#                      address                                           agent  \
# 1         1/10 Wright Street                                    not recorded
# 5     1/63 Palmerston Street                                     Carlos Lehn
# 6        10 Pisconeri Street                                  Daniel Porcaro
# 7         10 Robinson Avenue                                   Claude Iaconi
# 8        10/10 Wright Street                                    not recorded
# ...                      ...                                             ...
# 1592    221 Newcastle Street                  Limnios Property Group - Perth
# 1597       10/5 Antonas Road      Capital First National - Alexander Heights
# 1600  21 Little Shenton Lane                 Nicheliving Real Estate - Perth
# 1610         7 Davies Street  Abel McGrath the Property People - Leederville
# 1615       25/20 Pendal Lane                     For Sale By Owner Australia
#
#       bathrooms  bedrooms  building_size  built_date  car_space  \
# 1             1         2             62        1979          1
# 5             2         3            185        2000          2
# 6             2         4            289        2008          3
# 7             2         2            174        1995          2
# 8             1         2             62        1979          1
# ...         ...       ...            ...         ...        ...
# 1592          1         2            108        1920          1
# 1597          1         1             67        2010          1
# 1600          2         3            121        1995          2
# 1610          2         3            227        2005          2
# 1615          2         3            161        2003          2
#
#                                     full_address  land_size        lat  \
# 1               1/10 Wright Street Perth WA 6000         62 -31.940382
# 5           1/63 Palmerston Street Perth WA 6000        176 -31.939400
# 6              10 Pisconeri Street Perth WA 6000        302 -31.948521
# 7               10 Robinson Avenue Perth WA 6000        241 -31.944291
# 8              10/10 Wright Street Perth WA 6000         62 -31.943972
# ...                                          ...        ...        ...
# 1592    221 Newcastle Street Northbridge WA 6003        179 -31.946080
# 1597       10/5 Antonas Road Northbridge WA 6003         93 -31.944030
# 1600  21 Little Shenton Lane Northbridge WA 6003        196 -31.946116
# 1610         7 Davies Street Northbridge WA 6003        255 -31.944449
# 1615       25/20 Pendal Lane Northbridge WA 6003        203 -31.942841
#
#              lng  postcode    price property_type  rent rent_date  sale_id  \
# 1     115.873713      6000   355000     Townhouse   340   2018-01        2
# 5     115.859400      6000   821000         House     0   1900-01        6
# 6     115.867500      6000  1308000         House   700   2018-01        7
# 7     115.864298      6000   880000         House   550   2018-01        8
# 8     115.871931      6000   447500     Townhouse   460   2013-01        9
# ...          ...       ...      ...           ...   ...       ...      ...
# 1592  115.860120      6003   640000         House   450   2011-01     1593
# 1597  115.854829      6003   440000         House   430   2010-01     1598
# 1600  115.853643      6003   785000     Townhouse   600   2020-01     1601
# 1610  115.855850      6003  1025000         House     0   1900-01     1611
# 1615  115.856104      6003   724999     Townhouse   590   2018-01     1616
#
#      sold_date state       suburb
# 1      2020-01    WA        Perth
# 5      2019-01    WA        Perth
# 6      2021-01    WA        Perth
# 7      2020-01    WA        Perth
# 8      2020-01    WA        Perth
# ...        ...   ...          ...
# 1592   2014-01    WA  Northbridge
# 1597   2014-01    WA  Northbridge
# 1600   2013-01    WA  Northbridge
# 1610   2013-01    WA  Northbridge
# 1615   2013-01    WA  Northbridge
#
# [482 rows x 20 columns]

# %%
house.columns
# Out:
# Index(['address', 'agent', 'bathrooms', 'bedrooms', 'building_size',
#        'built_date', 'car_space', 'full_address', 'land_size', 'lat', 'lng',
#        'postcode', 'price', 'property_type', 'rent', 'rent_date', 'sale_id',
#        'sold_date', 'state', 'suburb'],
#       dtype='object')

# %%
# Assign the data to X and y
X = house[["bedrooms", "bathrooms", "car_space", "land_size", "building_size", "built_date", "postcode"]]
y = house["price"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (482, 7) (482, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data

X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)

# %%
# Transform the training and testing data using the X_scaler and y_scaler models

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
# Create the model using LinearRegression

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression()

# %%
# Make predictions using a fitted model
predictions = model.predict(X_test_scaled)
model.fit(X_train_scaled, y_train_scaled)
plt.scatter(model.predict(X_train_scaled), y_train_scaled - model.predict(X_train_scaled), c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), y_test_scaled - model.predict(X_test_scaled), c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()

# %%
# Fit the model to the training data and calculate the scores for the training and testing data

training_score = model.score(X_train_scaled, y_train_scaled)
testing_score = model.score(X_test_scaled, y_test_scaled)

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.704890190019361
# Testing Score: 0.7396575273231953

# %%
# Used X_test_scaled, y_test_scaled, and model.predict(X_test_scaled) to calculate MSE and R2

from sklearn.metrics import mean_squared_error

MSE = mean_squared_error(y_test_scaled, predictions)
r2 = model.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.22616846437224017, R2: 0.7402941130815941

# %%
# LASSO model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Lasso


lasso = Lasso(alpha=.01).fit(X_train_scaled, y_train_scaled)

lasso_predictions = lasso.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, lasso_predictions) #error to a model (closer to 0 the better)
r2 = lasso.score(X_test_scaled, y_test_scaled) #nearer to 1 the better

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.3140975669536798, R2: 0.7369868473665199

# %%
# Ridge model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import Ridge


ridge = Ridge(alpha=.01).fit(X_train_scaled, y_train_scaled)

ridge_predictions = ridge.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, ridge_predictions)
r2 = ridge.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.3109124468530574, R2: 0.7396539437318492

# %%
# ElasticNet model
# Note: Use an alpha of .01 when creating the model for this activity
from sklearn.linear_model import ElasticNet

elasticnet = ElasticNet(alpha=.01).fit(X_train_scaled, y_train_scaled)

elas_predictions = elasticnet.predict(X_test_scaled)

MSE = mean_squared_error(y_test_scaled, elas_predictions)
r2 = elasticnet.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.3131970894267142, R2: 0.7377408724152963

# %%
#test
# suburb needs to be categorical
X_test = X_scaler.transform([[4,2,6,1012,327,1945,6009]])
predictions = model.predict(X_test)
results = y_scaler.inverse_transform(predictions)
results

#to try deeplearning model
# Out:
# array([[2061732.40304908]])
