# %% [markdown]
# # Data Cleaning

# %%
# Dependencies
import pandas as pd
from datetime import datetime as dt

from sqlalchemy import create_engine

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import inspect

from sqlalchemy import Column, Float, Integer, String
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# %%
perth = pd.read_csv("static/data/Perth.csv")
west_perth = pd.read_csv("static/data/WestPerth.csv")
east_perth = pd.read_csv("static/data/EastPerth.csv")
crawley = pd.read_csv("static/data/Crawley.csv")
nedlands = pd.read_csv("static/data/Nedlands.csv")
northbridge = pd.read_csv("static/data/Northbridge.csv")

northbridge
# Out:
#                      address       suburb state  postcode  \
# 0        6/11 Shenton Street  Northbridge    WA      6003
# 1     4/335 Newcastle Street  Northbridge    WA      6003
# 2       2/89 Aberdeen Street  Northbridge    WA      6003
# 3          2/2 Davies Street  Northbridge    WA      6003
# 4       39/258-264 Newcastle  Northbridge    WA      6003
# ..                       ...          ...   ...       ...
# 245        25/20 Pendal Lane  Northbridge    WA      6003
# 246  21/145 Newcastle Street  Northbridge    WA      6003
# 247   18/76 Newcastle Street  Northbridge    WA      6003
# 248        10/89 Lake Street  Northbridge    WA      6003
# 249        13/10 Pendal Lane  Northbridge    WA      6003
#
#                                     full_address     price  sold date  \
# 0        6/11 Shenton Street Northbridge WA 6003  $440,000  1/07/2021
# 1     4/335 Newcastle Street Northbridge WA 6003  $320,000  1/05/2021
# 2       2/89 Aberdeen Street Northbridge WA 6003  $379,000  1/05/2021
# 3          2/2 Davies Street Northbridge WA 6003  $333,000  1/05/2021
# 4       39/258-264 Newcastle Northbridge WA 6003  $526,350  1/05/2021
# ..                                           ...       ...        ...
# 245        25/20 Pendal Lane Northbridge WA 6003  $724,999  1/07/2013
# 246  21/145 Newcastle Street Northbridge WA 6003  $614,000  1/07/2013
# 247   18/76 Newcastle Street Northbridge WA 6003  $535,000  1/07/2013
# 248        10/89 Lake Street Northbridge WA 6003  $590,000  1/06/2013
# 249        13/10 Pendal Lane Northbridge WA 6003  $560,000  1/06/2013
#
#           type  bedrooms  bathrooms  car space  Land size  Building size  \
# 0    Apartment         2          1          1        108           84.0
# 1    Apartment         1          1          1         82           56.0
# 2    Apartment         2          1          1         99           67.0
# 3         Unit         1          1          1         83           58.0
# 4    Apartment         2          2          2        173          124.0
# ..         ...       ...        ...        ...        ...            ...
# 245  Townhouse         3          2          2        203          161.0
# 246  Apartment         3          2          1        151          104.0
# 247  Apartment         2          2          1        123           88.0
# 248  Apartment         3          2          1        139           99.0
# 249  Apartment         2          2          1        117           90.0
#
#     Year Built    rent  rent date                           agent        lat  \
# 0    1/01/1996  $475pw  1/12/2017                   Claude Iaconi -31.946108
# 1    1/01/2008  $300pw  1/09/2016                    not recorded -31.943918
# 2    1/01/2016  $380pw  1/08/2019                   Brendon Habak -31.946852
# 3    1/01/2006  $330pw  1/11/2018                    Arash Kalani -31.944023
# 4    1/01/2005       0  1/01/1900                    not recorded -31.944986
# ..         ...     ...        ...                             ...        ...
# 245  1/01/2003  $590pw  1/02/2018     For Sale By Owner Australia -31.942841
# 246  1/01/2009       0  1/01/1900   Realmark Central - East Perth -31.946895
# 247  1/01/2007  $530pw  1/01/2014     Abel Property - Leederville -31.948372
# 248  1/01/2009  $540pw  1/11/2011  BOSS Real Estate - Northbridge -31.945441
# 249  1/01/2003       0  1/01/1900         MLG Realty - EAST PERTH -31.943275
#
#             lng
# 0    115.854510
# 1    115.855434
# 2    115.858781
# 3    115.855711
# 4    115.858941
# ..          ...
# 245  115.856104
# 246  115.861846
# 247  115.866086
# 248  115.857860
# 249  115.856012
#
# [250 rows x 19 columns]

# %%
frames = [perth, west_perth, east_perth, crawley, nedlands, northbridge]

cityofperth_df = pd.concat(frames)

cityofperth_df
# Out:
#                      address       suburb state  postcode  \
# 0           1/10 Pendal Lane        Perth    WA      6000
# 1         1/10 Wright Street        Perth    WA      6000
# 2      1/308 Stirling Street        Perth    WA      6000
# 3        1/33 Windsor Street        Perth    WA      6000
# 4       1/478 William Street        Perth    WA      6000
# ..                       ...          ...   ...       ...
# 245        25/20 Pendal Lane  Northbridge    WA      6003
# 246  21/145 Newcastle Street  Northbridge    WA      6003
# 247   18/76 Newcastle Street  Northbridge    WA      6003
# 248        10/89 Lake Street  Northbridge    WA      6003
# 249        13/10 Pendal Lane  Northbridge    WA      6003
#
#                                     full_address     price  sold date  \
# 0                 1/10 Pendal Lane Perth WA 6000  $359,000  1/08/2020
# 1               1/10 Wright Street Perth WA 6000  $355,000  1/04/2020
# 2            1/308 Stirling Street Perth WA 6000  $325,000  1/05/2021
# 3              1/33 Windsor Street Perth WA 6000  $360,000  1/07/2020
# 4             1/478 William Street Perth WA 6000  $523,000  1/06/2021
# ..                                           ...       ...        ...
# 245        25/20 Pendal Lane Northbridge WA 6003  $724,999  1/07/2013
# 246  21/145 Newcastle Street Northbridge WA 6003  $614,000  1/07/2013
# 247   18/76 Newcastle Street Northbridge WA 6003  $535,000  1/07/2013
# 248        10/89 Lake Street Northbridge WA 6003  $590,000  1/06/2013
# 249        13/10 Pendal Lane Northbridge WA 6003  $560,000  1/06/2013
#
#           type  bedrooms  bathrooms  car space  Land size  Building size  \
# 0    Apartment       2.0        2.0        1.0       96.0           90.0
# 1    Townhouse       2.0        1.0        1.0       62.0           62.0
# 2         Unit       2.0        1.0        1.0       59.0           59.0
# 3    Apartment       2.0        2.0        1.0       97.0           56.0
# 4    Apartment       2.0        2.0        2.0      129.0           90.0
# ..         ...       ...        ...        ...        ...            ...
# 245  Townhouse       3.0        2.0        2.0      203.0          161.0
# 246  Apartment       3.0        2.0        1.0      151.0          104.0
# 247  Apartment       2.0        2.0        1.0      123.0           88.0
# 248  Apartment       3.0        2.0        1.0      139.0           99.0
# 249  Apartment       2.0        2.0        1.0      117.0           90.0
#
#     Year Built    rent  rent date                           agent        lat  \
# 0    1/01/2003  $470pw  1/06/2010                    not recorded -31.943275
# 1    1/01/1979  $340pw  1/10/2018                    not recorded -31.940382
# 2    1/01/1965  $300pw  1/04/2012                    Peter Thomas -31.942238
# 3    1/01/2016  $360pw  1/03/2020                    not recorded -31.944320
# 4    1/01/2009  $475pw  1/07/2020                    not recorded -31.941260
# ..         ...     ...        ...                             ...        ...
# 245  1/01/2003  $590pw  1/02/2018     For Sale By Owner Australia -31.942841
# 246  1/01/2009       0  1/01/1900   Realmark Central - East Perth -31.946895
# 247  1/01/2007  $530pw  1/01/2014     Abel Property - Leederville -31.948372
# 248  1/01/2009  $540pw  1/11/2011  BOSS Real Estate - Northbridge -31.945441
# 249  1/01/2003       0  1/01/1900         MLG Realty - EAST PERTH -31.943275
#
#             lng
# 0    115.856012
# 1    115.873713
# 2    115.869436
# 3    115.874520
# 4    115.863844
# ..          ...
# 245  115.856104
# 246  115.861846
# 247  115.866086
# 248  115.857860
# 249  115.856012
#
# [1692 rows x 19 columns]

# %%
cityofperth_df = cityofperth_df.dropna()

cityofperth_df
# Out:
#                      address       suburb state  postcode  \
# 0           1/10 Pendal Lane        Perth    WA      6000
# 1         1/10 Wright Street        Perth    WA      6000
# 2      1/308 Stirling Street        Perth    WA      6000
# 3        1/33 Windsor Street        Perth    WA      6000
# 4       1/478 William Street        Perth    WA      6000
# ..                       ...          ...   ...       ...
# 245        25/20 Pendal Lane  Northbridge    WA      6003
# 246  21/145 Newcastle Street  Northbridge    WA      6003
# 247   18/76 Newcastle Street  Northbridge    WA      6003
# 248        10/89 Lake Street  Northbridge    WA      6003
# 249        13/10 Pendal Lane  Northbridge    WA      6003
#
#                                     full_address     price  sold date  \
# 0                 1/10 Pendal Lane Perth WA 6000  $359,000  1/08/2020
# 1               1/10 Wright Street Perth WA 6000  $355,000  1/04/2020
# 2            1/308 Stirling Street Perth WA 6000  $325,000  1/05/2021
# 3              1/33 Windsor Street Perth WA 6000  $360,000  1/07/2020
# 4             1/478 William Street Perth WA 6000  $523,000  1/06/2021
# ..                                           ...       ...        ...
# 245        25/20 Pendal Lane Northbridge WA 6003  $724,999  1/07/2013
# 246  21/145 Newcastle Street Northbridge WA 6003  $614,000  1/07/2013
# 247   18/76 Newcastle Street Northbridge WA 6003  $535,000  1/07/2013
# 248        10/89 Lake Street Northbridge WA 6003  $590,000  1/06/2013
# 249        13/10 Pendal Lane Northbridge WA 6003  $560,000  1/06/2013
#
#           type  bedrooms  bathrooms  car space  Land size  Building size  \
# 0    Apartment       2.0        2.0        1.0       96.0           90.0
# 1    Townhouse       2.0        1.0        1.0       62.0           62.0
# 2         Unit       2.0        1.0        1.0       59.0           59.0
# 3    Apartment       2.0        2.0        1.0       97.0           56.0
# 4    Apartment       2.0        2.0        2.0      129.0           90.0
# ..         ...       ...        ...        ...        ...            ...
# 245  Townhouse       3.0        2.0        2.0      203.0          161.0
# 246  Apartment       3.0        2.0        1.0      151.0          104.0
# 247  Apartment       2.0        2.0        1.0      123.0           88.0
# 248  Apartment       3.0        2.0        1.0      139.0           99.0
# 249  Apartment       2.0        2.0        1.0      117.0           90.0
#
#     Year Built    rent  rent date                           agent        lat  \
# 0    1/01/2003  $470pw  1/06/2010                    not recorded -31.943275
# 1    1/01/1979  $340pw  1/10/2018                    not recorded -31.940382
# 2    1/01/1965  $300pw  1/04/2012                    Peter Thomas -31.942238
# 3    1/01/2016  $360pw  1/03/2020                    not recorded -31.944320
# 4    1/01/2009  $475pw  1/07/2020                    not recorded -31.941260
# ..         ...     ...        ...                             ...        ...
# 245  1/01/2003  $590pw  1/02/2018     For Sale By Owner Australia -31.942841
# 246  1/01/2009       0  1/01/1900   Realmark Central - East Perth -31.946895
# 247  1/01/2007  $530pw  1/01/2014     Abel Property - Leederville -31.948372
# 248  1/01/2009  $540pw  1/11/2011  BOSS Real Estate - Northbridge -31.945441
# 249  1/01/2003       0  1/01/1900         MLG Realty - EAST PERTH -31.943275
#
#             lng
# 0    115.856012
# 1    115.873713
# 2    115.869436
# 3    115.874520
# 4    115.863844
# ..          ...
# 245  115.856104
# 246  115.861846
# 247  115.866086
# 248  115.857860
# 249  115.856012
#
# [1620 rows x 19 columns]

# %%
#to remove '$' from price
cityofperth_df['price'] = cityofperth_df['price'].map(lambda x: x.lstrip('$'))
# Out:
# C:\Users\helena\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#to remove ',' from price
cityofperth_df['price'] = cityofperth_df['price'].str.replace(',', '')
# Out:
# C:\Users\helena\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
cityofperth_df['price']
# Out:
# 0      359000
# 1      355000
# 2      325000
# 3      360000
# 4      523000
#         ...
# 245    724999
# 246    614000
# 247    535000
# 248    590000
# 249    560000
# Name: price, Length: 1620, dtype: object

# %%
#to remove '$' and 'pw' from rent
cityofperth_df['rent'] = cityofperth_df['rent'].map(lambda x: x.lstrip('$').rstrip('pw'))
# Out:
# C:\Users\helena\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
cityofperth_df['rent']
# Out:
# 0      470
# 1      340
# 2      300
# 3      360
# 4      475
#       ...
# 245    590
# 246      0
# 247    530
# 248    540
# 249      0
# Name: rent, Length: 1620, dtype: object

# %%
cityofperth_df.dtypes
# Out:
# address           object
# suburb            object
# state             object
# postcode           int64
# full_address      object
# price             object
# sold date         object
# type              object
# bedrooms         float64
# bathrooms        float64
# car space        float64
# Land size        float64
# Building size    float64
# Year Built        object
# rent              object
# rent date         object
# agent             object
# lat              float64
# lng              float64
# dtype: object

# %%
#convert all datatypes to be able to fit in SQLite
cityofperth_df['address'] = cityofperth_df['address'].astype('string')
cityofperth_df['suburb'] = cityofperth_df['suburb'].astype('string')
cityofperth_df['state'] = cityofperth_df['state'].astype('string')
cityofperth_df['full_address'] = cityofperth_df['full_address'].astype('string')
cityofperth_df['type'] = cityofperth_df['type'].astype('string')
cityofperth_df['price'] = cityofperth_df['price'].astype('float64')
cityofperth_df['sold date'] = cityofperth_df['sold date'].astype('datetime64[ns]')
cityofperth_df['Land size'] = cityofperth_df['Land size'].astype('float64')
cityofperth_df['Year Built'] = cityofperth_df['Year Built'].astype('datetime64[ns]')
cityofperth_df['rent'] = cityofperth_df['rent'].astype('float64')
cityofperth_df['rent date'] = cityofperth_df['rent date'].astype('datetime64[ns]')
cityofperth_df['agent'] = cityofperth_df['agent'].astype('string')

cityofperth_df.dtypes
# Out:
# C:\Users\helena\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\helena\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\helena\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\helena\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\helena\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\helena\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\helena\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\helena\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\helena\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\helena\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\helena\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\helena\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# address                  string
# suburb                   string
# state                    string
# postcode                  int64
# full_address             string
# price                   float64
# sold date        datetime64[ns]
# type                     string
# bedrooms                float64
# bathrooms               float64
# car space               float64
# Land size               float64
# Building size           float64
# Year Built       datetime64[ns]
# rent                    float64
# rent date        datetime64[ns]
# agent                    string
# lat                     float64
# lng                     float64
# dtype: object

# %%
cityofperth_df.head(5)
# Out:
#                  address suburb state  postcode  \
# 0       1/10 Pendal Lane  Perth    WA      6000
# 1     1/10 Wright Street  Perth    WA      6000
# 2  1/308 Stirling Street  Perth    WA      6000
# 3    1/33 Windsor Street  Perth    WA      6000
# 4   1/478 William Street  Perth    WA      6000
#
#                           full_address     price  sold date       type  \
# 0       1/10 Pendal Lane Perth WA 6000  359000.0 2020-01-08  Apartment
# 1     1/10 Wright Street Perth WA 6000  355000.0 2020-01-04  Townhouse
# 2  1/308 Stirling Street Perth WA 6000  325000.0 2021-01-05       Unit
# 3    1/33 Windsor Street Perth WA 6000  360000.0 2020-01-07  Apartment
# 4   1/478 William Street Perth WA 6000  523000.0 2021-01-06  Apartment
#
#    bedrooms  bathrooms  car space  Land size  Building size Year Built   rent  \
# 0       2.0        2.0        1.0       96.0           90.0 2003-01-01  470.0
# 1       2.0        1.0        1.0       62.0           62.0 1979-01-01  340.0
# 2       2.0        1.0        1.0       59.0           59.0 1965-01-01  300.0
# 3       2.0        2.0        1.0       97.0           56.0 2016-01-01  360.0
# 4       2.0        2.0        2.0      129.0           90.0 2009-01-01  475.0
#
#    rent date         agent        lat         lng
# 0 2010-01-06  not recorded -31.943275  115.856012
# 1 2018-01-10  not recorded -31.940382  115.873713
# 2 2012-01-04  Peter Thomas -31.942238  115.869436
# 3 2020-01-03  not recorded -31.944320  115.874520
# 4 2020-01-07  not recorded -31.941260  115.863844

# %%
# renaming columns to have the similar formatting
cityofperth_df = cityofperth_df.rename(columns= {'Year Built':'built_date', 'Land size':'land_size',
                                                 'Building size':'building_size', 'sold date':'sold_date' , 
                                                 'car space':'car_space', 'rent date':'rent_date' ,
                                                'type':'property_type'})

# %%
cityofperth_df.to_csv('static/data/cityofperth.csv')

# %%
cityofperth_df.dtypes
# Out:
# address                  string
# suburb                   string
# state                    string
# postcode                  int64
# full_address             string
# price                   float64
# sold_date        datetime64[ns]
# property_type            string
# bedrooms                float64
# bathrooms               float64
# car_space               float64
# land_size               float64
# building_size           float64
# built_date       datetime64[ns]
# rent                    float64
# rent_date        datetime64[ns]
# agent                    string
# lat                     float64
# lng                     float64
# dtype: object

# %%
cityofperth_df.columns
# Out:
# Index(['address', 'suburb', 'state', 'postcode', 'full_address', 'price',
#        'sold_date', 'property_type', 'bedrooms', 'bathrooms', 'car_space',
#        'land_size', 'building_size', 'built_date', 'rent', 'rent_date',
#        'agent', 'lat', 'lng'],
#       dtype='object')

# %%
cityofperth_df =  cityofperth_df[['full_address', 'price',
       'sold_date', 'property_type', 'bedrooms', 'bathrooms', 'car_space',
       'land_size', 'building_size', 'built_date', 'rent', 'rent_date',
       'agent', 'lat', 'lng', 'address', 'suburb', 'state', 'postcode']]
cityofperth_df.head()
# Out:
#                           full_address     price  sold_date property_type  \
# 0       1/10 Pendal Lane Perth WA 6000  359000.0 2020-01-08     Apartment
# 1     1/10 Wright Street Perth WA 6000  355000.0 2020-01-04     Townhouse
# 2  1/308 Stirling Street Perth WA 6000  325000.0 2021-01-05          Unit
# 3    1/33 Windsor Street Perth WA 6000  360000.0 2020-01-07     Apartment
# 4   1/478 William Street Perth WA 6000  523000.0 2021-01-06     Apartment
#
#    bedrooms  bathrooms  car_space  land_size  building_size built_date   rent  \
# 0       2.0        2.0        1.0       96.0           90.0 2003-01-01  470.0
# 1       2.0        1.0        1.0       62.0           62.0 1979-01-01  340.0
# 2       2.0        1.0        1.0       59.0           59.0 1965-01-01  300.0
# 3       2.0        2.0        1.0       97.0           56.0 2016-01-01  360.0
# 4       2.0        2.0        2.0      129.0           90.0 2009-01-01  475.0
#
#    rent_date         agent        lat         lng                address  \
# 0 2010-01-06  not recorded -31.943275  115.856012       1/10 Pendal Lane
# 1 2018-01-10  not recorded -31.940382  115.873713     1/10 Wright Street
# 2 2012-01-04  Peter Thomas -31.942238  115.869436  1/308 Stirling Street
# 3 2020-01-03  not recorded -31.944320  115.874520    1/33 Windsor Street
# 4 2020-01-07  not recorded -31.941260  115.863844   1/478 William Street
#
#   suburb state  postcode
# 0  Perth    WA      6000
# 1  Perth    WA      6000
# 2  Perth    WA      6000
# 3  Perth    WA      6000
# 4  Perth    WA      6000

# %%
# Change date columns to string
cityofperth_df['sold_date'] = cityofperth_df['sold_date'].dt.strftime('%Y-%m')
cityofperth_df['built_date'] = cityofperth_df['built_date'].dt.strftime('%Y')
cityofperth_df['rent_date'] = cityofperth_df['rent_date'].dt.strftime('%Y-%m')

# %%
# Change date columns to string
cityofperth_df['sold_date'] = cityofperth_df['sold_date'].astype('string')
cityofperth_df['built_date'] = cityofperth_df['built_date'].astype('string')
cityofperth_df['rent_date'] = cityofperth_df['rent_date'].astype('string')

# %%
cityofperth_df.head()
# Out:
#                                     full_address     price sold_date  \
# 0                 1/10 Pendal Lane Perth WA 6000  359000.0   2020-01
# 1               1/10 Wright Street Perth WA 6000  355000.0   2020-01
# 2            1/308 Stirling Street Perth WA 6000  325000.0   2021-01
# 3              1/33 Windsor Street Perth WA 6000  360000.0   2020-01
# 4             1/478 William Street Perth WA 6000  523000.0   2021-01
# ..                                           ...       ...       ...
# 245        25/20 Pendal Lane Northbridge WA 6003  724999.0   2013-01
# 246  21/145 Newcastle Street Northbridge WA 6003  614000.0   2013-01
# 247   18/76 Newcastle Street Northbridge WA 6003  535000.0   2013-01
# 248        10/89 Lake Street Northbridge WA 6003  590000.0   2013-01
# 249        13/10 Pendal Lane Northbridge WA 6003  560000.0   2013-01
#
#     property_type  bedrooms  bathrooms  car_space  land_size  building_size  \
# 0       Apartment       2.0        2.0        1.0       96.0           90.0
# 1       Townhouse       2.0        1.0        1.0       62.0           62.0
# 2            Unit       2.0        1.0        1.0       59.0           59.0
# 3       Apartment       2.0        2.0        1.0       97.0           56.0
# 4       Apartment       2.0        2.0        2.0      129.0           90.0
# ..            ...       ...        ...        ...        ...            ...
# 245     Townhouse       3.0        2.0        2.0      203.0          161.0
# 246     Apartment       3.0        2.0        1.0      151.0          104.0
# 247     Apartment       2.0        2.0        1.0      123.0           88.0
# 248     Apartment       3.0        2.0        1.0      139.0           99.0
# 249     Apartment       2.0        2.0        1.0      117.0           90.0
#
#     built_date   rent rent_date                           agent        lat  \
# 0         2003  470.0   2010-01                    not recorded -31.943275
# 1         1979  340.0   2018-01                    not recorded -31.940382
# 2         1965  300.0   2012-01                    Peter Thomas -31.942238
# 3         2016  360.0   2020-01                    not recorded -31.944320
# 4         2009  475.0   2020-01                    not recorded -31.941260
# ..         ...    ...       ...                             ...        ...
# 245       2003  590.0   2018-01     For Sale By Owner Australia -31.942841
# 246       2009    0.0   1900-01   Realmark Central - East Perth -31.946895
# 247       2007  530.0   2014-01     Abel Property - Leederville -31.948372
# 248       2009  540.0   2011-01  BOSS Real Estate - Northbridge -31.945441
# 249       2003    0.0   1900-01         MLG Realty - EAST PERTH -31.943275
#
#             lng                  address       suburb state  postcode
# 0    115.856012         1/10 Pendal Lane        Perth    WA      6000
# 1    115.873713       1/10 Wright Street        Perth    WA      6000
# 2    115.869436    1/308 Stirling Street        Perth    WA      6000
# 3    115.874520      1/33 Windsor Street        Perth    WA      6000
# 4    115.863844     1/478 William Street        Perth    WA      6000
# ..          ...                      ...          ...   ...       ...
# 245  115.856104        25/20 Pendal Lane  Northbridge    WA      6003
# 246  115.861846  21/145 Newcastle Street  Northbridge    WA      6003
# 247  115.866086   18/76 Newcastle Street  Northbridge    WA      6003
# 248  115.857860        10/89 Lake Street  Northbridge    WA      6003
# 249  115.856012        13/10 Pendal Lane  Northbridge    WA      6003
#
# [1620 rows x 19 columns]

# %%
cityofperth_df.dtypes
# Out:
# full_address      string
# price            float64
# sold_date         string
# property_type     string
# bedrooms         float64
# bathrooms        float64
# car_space        float64
# land_size        float64
# building_size    float64
# built_date        string
# rent             float64
# rent_date         string
# agent             string
# lat              float64
# lng              float64
# address           string
# suburb            string
# state             string
# postcode           int64
# dtype: object

# %% [markdown]
# # Export DataFrame to SQLite table

# %%
# Establish database connection
engine = create_engine('sqlite:///SQL/CityOfPerth.sqlite')
conn = engine.connect()

# %%
# Define our perthcity table
class PerthCity(Base):
    __tablename__ = 'perthcity'
    sale_id = Column(Integer, primary_key=True)
    full_address = Column(String)
    price = Column(Float)
    sold_date = Column(String)
    property_type = Column(String)
    bedrooms = Column(Float)
    bathrooms = Column(Float)
    car_space = Column(Float)
    land_size = Column(Float)
    building_size = Column(Float)
    built_date = Column(String)
    rent = Column(Float)
    rent_date = Column(String)
    agent = Column(String)
    lat = Column(Float)
    lng = Column(Float)
    address = Column(String)
    suburb  = Column(String)
    state = Column(String)
    postcode = Column(Integer)

# %%
# # Define our perthcity table
# class PerthCity(Base):
#     __tablename__ = 'perthcity'
#     full_address = Column(VARCHAR, primary_key=True)
#     price = Column(Float)
#     sold_date = Column(varchar)
#     property_type = Column(varchar)
#     bedrooms = Column(Float)
#     bathrooms = Column(Float)
#     car_space = Column(Float)
#     land_size = Column(Float)
#     building_size = Column(Float)
#     built_date = Column(varchar)
#     rent = Column(Float)
#     rent_date = Column(varchar)
#     agent = Column(varchar)
#     lat = Column(Float)
#     lng = Column(Float)
#     address = Column(varchar)
#     suburb  = Column(varchar)
#     state = Column(varchar)
#     postcode = Column(Integer)

# %%
# Create the table within the database
Base.metadata.create_all(engine)

# %%
# Load data into table
cityofperth_df.to_sql('perthcity', engine, if_exists="append", index=False)

# %%
# Reflect the database tables
Base = automap_base()
Base.prepare(engine, reflect=True)

# %%
# Print all of the classes mapped to the Base
Base.classes.keys()
# Out:
# ['perthcity']

# %%
# Create a session
session = Session(engine)

# %%
# Assign the class to related variable
PerthCity = Base.classes.perthcity

# %%
# Use the session to query PerthCity table 
for row in session.query(PerthCity.sale_id, PerthCity.full_address, PerthCity.price, PerthCity.sold_date).limit(20).all():
    print(row)
# Out:
# (1, '1/10 Pendal Lane Perth WA 6000', 359000.0, '2020-01')
# (2, '1/10 Wright Street Perth WA 6000', 355000.0, '2020-01')
# (3, '1/308 Stirling Street Perth WA 6000', 325000.0, '2021-01')
# (4, '1/33 Windsor Street Perth WA 6000', 360000.0, '2020-01')
# (5, '1/478 William Street Perth WA 6000', 523000.0, '2021-01')
# (6, '1/63 Palmerston Street Perth WA 6000', 821000.0, '2019-01')
# (7, '10 Pisconeri Street Perth WA 6000', 1308000.0, '2021-01')
# (8, '10 Robinson Avenue Perth WA 6000', 880000.0, '2020-01')
# (9, '10/10 Wright Street Perth WA 6000', 447500.0, '2020-01')
# (10, '10/20 Pendal Lane Perth WA 6000', 390000.0, '2021-01')
# (11, '100/101 Murray Street Perth WA 6000', 330000.0, '2020-01')
# (12, '100/22 St Georges Terrace Perth WA 6000', 385000.0, '2020-01')
# (13, '1013/380 Murray Street Perth WA 6000', 399950.0, '2020-01')
# (14, '104/15 Aberdeen Street Perth WA 6000', 409000.0, '2020-01')
# (15, '104/305 Murray Street Perth WA 6000', 245000.0, '2021-01')
# (16, '105/22 St Georges Terrace Perth WA 6000', 630000.0, '2019-01')
# (17, '106/580 Hay Street Perth WA 6000', 425000.0, '2020-01')
# (18, '107/101 Murray Street Perth WA 6000', 350000.0, '2021-01')
# (19, '108/126 Mounts Bay Road Perth WA 6000', 220000.0, '2019-01')
# (20, '109/15 Aberdeen Street Perth WA 6000', 330000.0, '2021-01')

# %%
cityofperth_df.columns
# Out:
# Index(['full_address', 'price', 'sold_date', 'property_type', 'bedrooms',
#        'bathrooms', 'car_space', 'land_size', 'building_size', 'built_date',
#        'rent', 'rent_date', 'agent', 'lat', 'lng', 'address', 'suburb',
#        'state', 'postcode'],
#       dtype='object')
