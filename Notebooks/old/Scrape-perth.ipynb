# %%
# Dependencies
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import requests
import numpy as np

# %%
# Setup splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 92.0.4515
# Get LATEST driver version for 92.0.4515
# Driver [C:\Users\John\.wdm\drivers\chromedriver\win32\92.0.4515.107\chromedriver.exe] found in cache

# %%
# URL of page to be scraped
url = 'http://house.speakingsame.com/p.php?q=Perth%2C+WA'
browser.visit(url)

# %%
addresses = []
properties_info = []

pages = np.arange(0, 3, 1)

for page in pages:
    
    page_url = "http://house.speakingsame.com/p.php?q=Perth&p="+ str(page) +"&s=1&st=&type=&count=300&region=Perth&lat=0&lng=0&sta=wa&htype=&agent=0&minprice=0&maxprice=0&minbed=0&maxbed=0&minland=0&maxland=0"
    
    browser.visit(page_url)
   
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')

    addr_spans = soup.find_all('span', class_='addr')

    for span in addr_spans:
        addresses.append(span.a.text)
    addresses

    tables = soup.find_all('table', style="font-size:13px") #tables list (except 0,1 index) contians list of properties in the page

    for i in range(2,12):
        try:
            info = []
            trs = tables[i].find_all('tr')
            for tr in trs:
                info.append(tr.td.text)
        except:
            info.append('')
        properties_info.append(info)
        
  
    
properties_info
# Out:
# [['Sold $516,000 in Jul 2021',
#   'Apartment: ',
#   'Land size: 157 sqm',
#   'Agent: David Airey',
#   'Street view | Nearby'],
#  ['Sold $325,000 in Jul 2021', 'Apartment: ', 'Street view | Nearby'],
#  ['Sold $373,000 in Jul 2021',
#   'Last Sold $361,000 in Mar 2009',
#   'Apartment: 2  1  1 ',
#   'Land size: 2,495 sqm | Building size: 100 sqm',
#   'Agent: Sam Dempsey',
#   'Spacious 2 bedroom top floor apartment in beautiful condition with many extras and secure parking. More information to follow. Register your interest today. Phone Ron Goddard 0449 757 945.more',
#   'Street view | Nearby'],
#  ['Sold $450,000 in Jul 2021',
#   'Rent $465pw in Nov 2016',
#   'Apartment: 2  2  1 ',
#   'Land size: 109 sqm | Building size: 70 sqm',
#   'Agent: Danielle Geagea',
#   'Street view | Nearby'],
#  ['Sold $802,000 in Jul 2021',
#   'Last Sold $735,000 in Sep 2013',
#   'Rent $590pw in Oct 2018',
#   'Townhouse: 3  1  2 ',
#   'Land size: 104 sqm',
#   "Agent: Annette O'Brien-Oxley",
#   'Lot/Plan No: 2/S009756more',
#   'Floorplan | Street view | Nearby'],
#  ['Sold $590,000 in Jul 2021',
#   'Rent $575pw in Jan 2019',
#   'Apartment: 2  2  1 ',
#   'Land size: 749 sqm | Building size: 83 sqm',
#   'Agent: Maurice Flores',
#   'Brand New, Eco Friendly Warehouse Living. Now complete and ready to move in, the brand new Soda apartments deliver eco-friendly urban living at its finest with the transformation of Perths...more',
#   'Floorplan | Street view | Nearby'],
#  ['Sold $500,000 in Jun 2021',
#   'Rent $690pw in Oct 2018',
#   'Apartment: 3  2  1 ',
#   'Land size: 1,405 sqm | Building size: 120 sqm',
#   'Agent: Matt McWaters',
#   'Street view | Nearby'],
#  ['Sold $815,000 in Jun 2021',
#   'Last Sold $735,000 in Aug 2011',
#   'Rent $600pw in May 2010',
#   'Apartment: 3  2  1 ',
#   'Land size: 2,143 sqm | Building size: 152 sqm',
#   'The Art of Living, in the Heart of Perth - Open Sat 14/6 12-12.40PM. This property is all about lifestyle and living well. In an envied inner city location on the beautiful and leafy Money Street...more',
#   'Floorplan | Street view | Nearby'],
#  ['Sold $245,000 in Jun 2021', 'Apartment: ', 'Street view | Nearby'],
#  ['Sold $365,000 in Jun 2021',
#   'Apartment: 1  1  1 ',
#   'Land size: 4,143 sqm | Building size: 70 sqm',
#   "Under Offer by Leon Siew. Perth City's finest example of sky-high luxury living! Sex and the City eat your heart out. Sitting high in this exclusive community is a sanctuary that makes inner-city...more",
#   'Street view | Nearby'],
#  ['Sold $585,000 in Jun 2021',
#   'Last Sold $560,000 in Oct 2018',
#   'Rent $580pw in Apr 2014',
#   'House: 2  2  1 ',
#   'Land size: 5,606 sqm',
#   'Agent: ROB STEFANOVSKI',
#   'HISTORIC TOWNHOUSE IN A SECURE COMPLEX!. 45/34 Palmerston Street, Perth Combining style & class in the ultimate inner-city location, this unique factory conversion townhouse is situated in a...more',
#   'Street view | Nearby'],
#  ['Sold $1,300,000 in Jun 2021',
#   'Apartment: ',
#   'Agent: Amy Di Vincenzo',
#   'Street view | Nearby'],
#  ['Sold $490,000 in Jun 2021',
#   'Rent $460pw in Nov 2019',
#   'House: 2  2  1 ',
#   'Land size: 1,603 sqm | Building size: 81 sqm',
#   "LIKE 'EM HOT??. Well check this one out! Mixing the relaxed pace, beautiful parklands and convenience of outer city living with the excitement and energy of near city living gives you the RARE...more",
#   'Street view | Nearby'],
#  ['Sold $445,000 in Jun 2021',
#   'Rent $450pw in May 2018',
#   'Apartment: 2  2  1 ',
#   'Land size: 105 sqm | Building size: 78 sqm',
#   'Agent: Josh Roberts',
#   'Street view | Nearby'],
#  ['Sold $620,000 in Jun 2021',
#   'Last Sold $445,000 in Jun 2005',
#   'Rent $475pw in Sep 2019',
#   'Townhouse: 3  1  1 ',
#   'Land size: 2,029 sqm | Building size: 133 sqm',
#   'Agent: Graeme Correy',
#   'Street view | Nearby'],
#  ['Sold $362,000 in Jun 2021',
#   'Rent $550pw in May 2014',
#   'Apartment: 1  1  1 ',
#   'Land size: 3,250 sqm',
#   'Agent: Joshua Leader',
#   'Street view | Nearby'],
#  ['Sold $1,050,000 in Jun 2021',
#   'House: 3  2  ',
#   'Land size: 198 sqm',
#   'Agent: Daniel Porcaro',
#   'Lot/Plan No: P004576 7more',
#   'Street view | Nearby'],
#  ['Sold $330,000 in Jun 2021',
#   'Rent $370pw in Mar 2019',
#   'Apartment: 1  1  1 ',
#   'Land size: 3,028 sqm',
#   'Agent: Cherry Li',
#   'Street view | Nearby'],
#  ['Sold $620,000 in Jun 2021',
#   'Last Sold $570,000 in Sep 2013(Auction)',
#   'Rent $500pw in Mar 2017',
#   'Apartment: 2  2  2 ',
#   'Land size: 5,596 sqm | Building size: 117 sqm',
#   'Agent: Nadija Begovich',
#   "UNDER OFFER!. The Rialto Terraces is one of the most sought after building's in the city fringe. Combining the character of an old 1930's warehouse and the best of modern living. This street...more",
#   'Floorplan | Street view | Nearby'],
#  ['Sold $315,000 in Jun 2021',
#   'Last Sold $284,000 in Mar 2006',
#   'Rent $335pw in Apr 2017',
#   'Apartment: 1  1  1 ',
#   'Land size: 3,356 sqm | Building size: 60 sqm',
#   'Agent: Dion Brown',
#   'Street view | Nearby'],
#  ['Sold $300,000 in Jun 2021',
#   'Apartment: ',
#   'Agent: Josh Roberts',
#   'Street view | Nearby'],
#  ['Sold $523,000 in Jun 2021',
#   'Rent $475pw in Jul 2020',
#   'Unit: 2  2  1 ',
#   'Land size: 129 sqm | Building size: 90 sqm',
#   'Street view | Nearby'],
#  ['Sold $2,700,000 in Jun 2021',
#   'Last Sold $2,455,000 in May 2015',
#   'Rent $4,000pw in Aug 2013',
#   'Apartment: 4  5  2 ',
#   'Land size: 509 sqm | Building size: 351 sqm',
#   'Sophisticated Penthouse Lifestyle in Elevation. Purchase a deluxe lifestyle not simply an apartment & be spoilt by sparkling Southerly river views & stunning City views from this brand new...more',
#   'Floorplan | Street view | Nearby'],
#  ['Sold $475,000 in Jun 2021',
#   'Apartment: ',
#   'Land size: 143 sqm',
#   'Agent: Daniel Porcaro',
#   'Street view | Nearby'],
#  ['Sold $399,500 in Jun 2021',
#   'Rent $470pw in Aug 2020',
#   'Apartment: 2  2  1 ',
#   'Agent: Veljko Lazovic',
#   'The King Of Lord Streetmore',
#   'Street view | Nearby'],
#  ['Sold $895,000 in May 2021',
#   'House: ',
#   'Land size: 128 sqm',
#   'Agent: Peter Menaglio',
#   ''],
#  ['Sold $480,000 in May 2021', 'Apartment: ', 'Street view | Nearby'],
#  ['Sold $1,308,000 in May 2021',
#   'Last Sold $990,000 in Dec 2019',
#   'Rent $700pw in Apr 2018',
#   'House: 4  2  3 ',
#   'Land size: 296 sqm',
#   'Agent: Daniel Porcaro',
#   'Lot/Plan No: P039555     816more',
#   'Street view | Nearby'],
#  ['Sold $2,650,000 in May 2021',
#   'Apartment: 4  5  4 ',
#   'Land size: 4,143 sqm | Building size: 351 sqm',
#   'The Last Elevation Penthouse on Offer!. Purchase a deluxe lifestyle not simply an apartment & be spoilt by sparkling Southerly river views & stunning City views from this brand new Penthouse in...more',
#   'Street view | Nearby'],
#  ['Sold $1,000,000 in May 2021',
#   'House: 3  2  5 ',
#   'Land size: 385 sqm',
#   'Agent: Ray Cafini',
#   'Lot/Plan No: P001372 3more',
#   'Street view | Nearby']]

# %%
tables = soup.find_all('table', style="font-size:13px") #tables list (except 0,1 index) contians list of properties in the page

# %%
addresses
# Out:
# ['39/128 Mounts Bay Road',
#  '32/418 Murray Street',
#  '40/120 Lake Street',
#  '11/177 Stirling Street',
#  '21 Myrtle Street',
#  '5/19 Lindsay Street',
#  '8/124 Mounts Bay Road',
#  '26/14 Money Street',
#  '104/305 Murray Street',
#  '401/237 Adelaide Terrace',
#  '45/34 Palmerston Street',
#  '2009/11 Barrack Square',
#  '25/226 Beaufort Street',
#  '30/69 Milligan Street',
#  '11/18 Robinson Avenue',
#  '56/378 Beaufort Street',
#  '172 Lake Street',
#  '109/15 Aberdeen Street',
#  '17/34 Palmerston Street',
#  '47/76 Newcastle Street',
#  '17/34 Bulwer Street',
#  '1/478 William Street',
#  '2701/237 Adelaide Terrace',
#  '601/112 Mounts Bay Road',
#  '73/262 Lord Street',
#  '48B Randell Street',
#  '36/10 Pendal Lane',
#  '10 Pisconeri Street',
#  '2801/237 Adelaide Terrace',
#  '392 Beaufort Street']

# %%
page_info = []
for i in range(2,12):
    try:
        info = []
        trs = tables[i].find_all('tr')
        for tr in trs:
            info.append(tr.td.text)
    except:
        info.append('')
    page_info.append(info)
page_info

# %%
Properties = []
for i in range(0, len(properties_info)):
    
    Property_dict = {}
    Property_dict['address'] = addresses[i]
    
    for j in range (0, len(properties_info[i])):
        
        try:
                    
            if properties_info[i][j].split(' ')[0] == "Sold": 
                Property_dict['price'] = properties_info[i][j].split(' ')[1]
                Property_dict['sold date'] = properties_info[i][j].split('in ')[1]

            if properties_info[i][j].split(' ')[0] in ["Apartment:", "House:", "Townhouse:"]:
                Property_dict['type'] = properties_info[i][j].split(' ')[0].split(':')[0]
                Property_dict['bedrooms'] = properties_info[i][j].split(' ')[1]
                try:
                    Property_dict['bathrooms'] = properties_info[i][j].split(' ')[3]
                except:
                    Property_dict['bathrooms'] = ''
                try:
                    Property_dict['car space'] = properties_info[i][j].split(' ')[5]
                except:
                    Property_dict['car space'] = ''
                    
            if properties_info[i][j].split(' ')[0] == "Agent:":
                Property_dict['agent'] = properties_info[i][j].split(': ')[1]
                
            if properties_info[i][j].split(' ')[0] == "Rent":
                Property_dict['rent'] = properties_info[i][j].split(' ')[1]
                Property_dict['rent date'] = properties_info[i][j].split('in ')[1]
                
            if properties_info[i][j].split(' ')[1] == "size:":
                if properties_info[i][j].split(' ')[0] == "Land":
                    Property_dict['Land size'] = properties_info[i][j].split(' ')[2]
                    try:
                        if properties_info[i][j].split(' ')[5] == "Building":
                            Property_dict['Building size'] = properties_info[i][j].split(' ')[7]
                    except:
                        continue
                elif properties_info[i][j].split(' ')[0] == "Building":
                    Property_dict['Building size'] = properties_info[i][j].split(' ')[2]
            
            
        except:
            continue

  
    Properties.append(Property_dict)
        
Properties
# Out:
# [{'address': '39/128 Mounts Bay Road',
#   'price': '$516,000',
#   'sold date': 'Jul 2021',
#   'type': 'Apartment',
#   'bedrooms': '',
#   'bathrooms': '',
#   'car space': '',
#   'Land size': '157',
#   'agent': 'David Airey'},
#  {'address': '32/418 Murray Street',
#   'price': '$325,000',
#   'sold date': 'Jul 2021',
#   'type': 'Apartment',
#   'bedrooms': '',
#   'bathrooms': '',
#   'car space': ''},
#  {'address': '40/120 Lake Street',
#   'price': '$373,000',
#   'sold date': 'Jul 2021',
#   'type': 'Apartment',
#   'bedrooms': '2',
#   'bathrooms': '1',
#   'car space': '1',
#   'Land size': '2,495',
#   'Building size': '100',
#   'agent': 'Sam Dempsey'},
#  {'address': '11/177 Stirling Street',
#   'price': '$450,000',
#   'sold date': 'Jul 2021',
#   'rent': '$465pw',
#   'rent date': 'Nov 2016',
#   'type': 'Apartment',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car space': '1',
#   'Land size': '109',
#   'Building size': '70',
#   'agent': 'Danielle Geagea'},
#  {'address': '21 Myrtle Street',
#   'price': '$802,000',
#   'sold date': 'Jul 2021',
#   'rent': '$590pw',
#   'rent date': 'Oct 2018',
#   'type': 'Townhouse',
#   'bedrooms': '3',
#   'bathrooms': '1',
#   'car space': '2',
#   'Land size': '104',
#   'agent': "Annette O'Brien-Oxley"},
#  {'address': '5/19 Lindsay Street',
#   'price': '$590,000',
#   'sold date': 'Jul 2021',
#   'rent': '$575pw',
#   'rent date': 'Jan 2019',
#   'type': 'Apartment',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car space': '1',
#   'Land size': '749',
#   'Building size': '83',
#   'agent': 'Maurice Flores'},
#  {'address': '8/124 Mounts Bay Road',
#   'price': '$500,000',
#   'sold date': 'Jun 2021',
#   'rent': '$690pw',
#   'rent date': 'Oct 2018',
#   'type': 'Apartment',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'car space': '1',
#   'Land size': '1,405',
#   'Building size': '120',
#   'agent': 'Matt McWaters'},
#  {'address': '26/14 Money Street',
#   'price': '$815,000',
#   'sold date': 'Jun 2021',
#   'rent': '$600pw',
#   'rent date': 'May 2010',
#   'type': 'Apartment',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'car space': '1',
#   'Land size': '2,143',
#   'Building size': '152'},
#  {'address': '104/305 Murray Street',
#   'price': '$245,000',
#   'sold date': 'Jun 2021',
#   'type': 'Apartment',
#   'bedrooms': '',
#   'bathrooms': '',
#   'car space': ''},
#  {'address': '401/237 Adelaide Terrace',
#   'price': '$365,000',
#   'sold date': 'Jun 2021',
#   'type': 'Apartment',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car space': '1',
#   'Land size': '4,143',
#   'Building size': '70'},
#  {'address': '45/34 Palmerston Street',
#   'price': '$585,000',
#   'sold date': 'Jun 2021',
#   'rent': '$580pw',
#   'rent date': 'Apr 2014',
#   'type': 'House',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car space': '1',
#   'Land size': '5,606',
#   'agent': 'ROB STEFANOVSKI'},
#  {'address': '2009/11 Barrack Square',
#   'price': '$1,300,000',
#   'sold date': 'Jun 2021',
#   'type': 'Apartment',
#   'bedrooms': '',
#   'bathrooms': '',
#   'car space': '',
#   'agent': 'Amy Di Vincenzo'},
#  {'address': '25/226 Beaufort Street',
#   'price': '$490,000',
#   'sold date': 'Jun 2021',
#   'rent': '$460pw',
#   'rent date': 'Nov 2019',
#   'type': 'House',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car space': '1',
#   'Land size': '1,603',
#   'Building size': '81'},
#  {'address': '30/69 Milligan Street',
#   'price': '$445,000',
#   'sold date': 'Jun 2021',
#   'rent': '$450pw',
#   'rent date': 'May 2018',
#   'type': 'Apartment',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car space': '1',
#   'Land size': '105',
#   'Building size': '78',
#   'agent': 'Josh Roberts'},
#  {'address': '11/18 Robinson Avenue',
#   'price': '$620,000',
#   'sold date': 'Jun 2021',
#   'rent': '$475pw',
#   'rent date': 'Sep 2019',
#   'type': 'Townhouse',
#   'bedrooms': '3',
#   'bathrooms': '1',
#   'car space': '1',
#   'Land size': '2,029',
#   'Building size': '133',
#   'agent': 'Graeme Correy'},
#  {'address': '56/378 Beaufort Street',
#   'price': '$362,000',
#   'sold date': 'Jun 2021',
#   'rent': '$550pw',
#   'rent date': 'May 2014',
#   'type': 'Apartment',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car space': '1',
#   'Land size': '3,250',
#   'agent': 'Joshua Leader'},
#  {'address': '172 Lake Street',
#   'price': '$1,050,000',
#   'sold date': 'Jun 2021',
#   'type': 'House',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'car space': '',
#   'Land size': '198',
#   'agent': 'Daniel Porcaro'},
#  {'address': '109/15 Aberdeen Street',
#   'price': '$330,000',
#   'sold date': 'Jun 2021',
#   'rent': '$370pw',
#   'rent date': 'Mar 2019',
#   'type': 'Apartment',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car space': '1',
#   'Land size': '3,028',
#   'agent': 'Cherry Li'},
#  {'address': '17/34 Palmerston Street',
#   'price': '$620,000',
#   'sold date': 'Jun 2021',
#   'rent': '$500pw',
#   'rent date': 'Mar 2017',
#   'type': 'Apartment',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car space': '2',
#   'Land size': '5,596',
#   'Building size': '117',
#   'agent': 'Nadija Begovich'},
#  {'address': '47/76 Newcastle Street',
#   'price': '$315,000',
#   'sold date': 'Jun 2021',
#   'rent': '$335pw',
#   'rent date': 'Apr 2017',
#   'type': 'Apartment',
#   'bedrooms': '1',
#   'bathrooms': '1',
#   'car space': '1',
#   'Land size': '3,356',
#   'Building size': '60',
#   'agent': 'Dion Brown'},
#  {'address': '17/34 Bulwer Street',
#   'price': '$300,000',
#   'sold date': 'Jun 2021',
#   'type': 'Apartment',
#   'bedrooms': '',
#   'bathrooms': '',
#   'car space': '',
#   'agent': 'Josh Roberts'},
#  {'address': '1/478 William Street',
#   'price': '$523,000',
#   'sold date': 'Jun 2021',
#   'rent': '$475pw',
#   'rent date': 'Jul 2020',
#   'Land size': '129',
#   'Building size': '90'},
#  {'address': '2701/237 Adelaide Terrace',
#   'price': '$2,700,000',
#   'sold date': 'Jun 2021',
#   'rent': '$4,000pw',
#   'rent date': 'Aug 2013',
#   'type': 'Apartment',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'car space': '2',
#   'Land size': '509',
#   'Building size': '351'},
#  {'address': '601/112 Mounts Bay Road',
#   'price': '$475,000',
#   'sold date': 'Jun 2021',
#   'type': 'Apartment',
#   'bedrooms': '',
#   'bathrooms': '',
#   'car space': '',
#   'Land size': '143',
#   'agent': 'Daniel Porcaro'},
#  {'address': '73/262 Lord Street',
#   'price': '$399,500',
#   'sold date': 'Jun 2021',
#   'rent': '$470pw',
#   'rent date': 'Aug 2020',
#   'type': 'Apartment',
#   'bedrooms': '2',
#   'bathrooms': '2',
#   'car space': '1',
#   'agent': 'Veljko Lazovic'},
#  {'address': '48B Randell Street',
#   'price': '$895,000',
#   'sold date': 'May 2021',
#   'type': 'House',
#   'bedrooms': '',
#   'bathrooms': '',
#   'car space': '',
#   'Land size': '128',
#   'agent': 'Peter Menaglio'},
#  {'address': '36/10 Pendal Lane',
#   'price': '$480,000',
#   'sold date': 'May 2021',
#   'type': 'Apartment',
#   'bedrooms': '',
#   'bathrooms': '',
#   'car space': ''},
#  {'address': '10 Pisconeri Street',
#   'price': '$1,308,000',
#   'sold date': 'May 2021',
#   'rent': '$700pw',
#   'rent date': 'Apr 2018',
#   'type': 'House',
#   'bedrooms': '4',
#   'bathrooms': '2',
#   'car space': '3',
#   'Land size': '296',
#   'agent': 'Daniel Porcaro'},
#  {'address': '2801/237 Adelaide Terrace',
#   'price': '$2,650,000',
#   'sold date': 'May 2021',
#   'type': 'Apartment',
#   'bedrooms': '4',
#   'bathrooms': '5',
#   'car space': '4',
#   'Land size': '4,143',
#   'Building size': '351'},
#  {'address': '392 Beaufort Street',
#   'price': '$1,000,000',
#   'sold date': 'May 2021',
#   'type': 'House',
#   'bedrooms': '3',
#   'bathrooms': '2',
#   'car space': '5',
#   'Land size': '385',
#   'agent': 'Ray Cafini'}]

# %%
len(Properties)
# Out:
# 30
